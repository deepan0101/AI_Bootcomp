# %%
from IPython import get_ipython
from IPython.display import display
# %%
import cv2 as cv
# Import the alternative imshow for Colab
from google.colab.patches import cv2_imshow

img = cv.imread("/content/boliviainteligente-z7ICBEMUJfw-unsplash.jpg")

# Use cv2_imshow instead of cv.imshow
cv2_imshow(img)

# cv.waitKey(0) is not needed with cv2_imshow as it displays the image directly
# k=cv.waitkey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=3840x2400>
